# %%
import pandas as pd
import numpy as np

# %%
path = r"D:\1B. COMPLETO_Bootcamp Desenvolvedor Python\Módulo 2 - Python para a análise de dados\pratica\pandas\spotify_top_1000_tracks.csv"
file = pd.read_csv(path)
file
# Out:
#                    track_name          artist  \
# 0    All The Stars (with SZA)  Kendrick Lamar
# 1                     Starboy      The Weeknd
# 2                    Señorita    Shawn Mendes
# 3                  Heat Waves   Glass Animals
# 4             Let Me Love You        DJ Snake
# ..                        ...             ...
# 995                      Lily           ISAEV
# 996                 Apologize       Besomorph
# 997                  I’m Good    Yohan Gerber
# 998                      Down       Arc North
# 999                Chandelier        Besomage
#
#                                                  album release_date  \
# 0    Black Panther The Album Music From And Inspire...   2018-02-09
# 1                                              Starboy   2016-11-25
# 2                                             Señorita   2019-06-21
# 3                                            Dreamland   2020-08-07
# ...

# %%
#Informações sobre o conjunto de dados
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_name    1000 non-null   object
#  1   artist        1000 non-null   object
#  2   album         1000 non-null   object
#  3   release_date  1000 non-null   object
#  4   popularity    1000 non-null   int64
#  5   spotify_url   1000 non-null   object
#  6   id            1000 non-null   object
#  7   duration_min  1000 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
#Estatísticas básicas
file.describe()
# Out:
#         popularity  duration_min
# count  1000.000000   1000.000000
# mean     56.669000      3.318516
# std      28.192805      0.849591
# min       0.000000      0.969150
# 25%      37.000000      2.754021
# 50%      68.000000      3.293833
# 75%      79.000000      3.745721
# max      97.000000      9.497883

# %%
#Localizando uma linha e coluna específica
print(file.iloc[1:3,4:6])
file.head(10)
# Out:
#    popularity                                        spotify_url
# 1          90  https://open.spotify.com/track/7MXVkk9YMctZqd1...
# 2          80  https://open.spotify.com/track/0TK2YIli7K1leLo...
#                         track_name                artist  \
# 0         All The Stars (with SZA)        Kendrick Lamar
# 1                          Starboy            The Weeknd
# 2                         Señorita          Shawn Mendes
# 3                       Heat Waves         Glass Animals
# 4                  Let Me Love You              DJ Snake
# 5                         La La La           Naughty Boy
# 6                       Apocalypse  Cigarettes After Sex
# 7                     Good For You          Selena Gomez
# 8                             Baby         Justin Bieber
# 9  There's Nothing Holdin' Me Back          Shawn Mendes
#
#                                                album release_date  popularity  \
# ...

# %%
#Indexação booleana

#Selecionando todos os dados com popularidade >90
file[file["popularity"]>80]
# Out:
#                       track_name                     artist  \
# 0       All The Stars (with SZA)             Kendrick Lamar
# 1                        Starboy                 The Weeknd
# 3                     Heat Waves              Glass Animals
# 4                Let Me Love You                   DJ Snake
# 8                           Baby              Justin Bieber
# ..                           ...                        ...
# 813       Thank You (Not So Bad)  Dimitri Vegas & Like Mike
# 815           I Don't Wanna Wait               David Guetta
# 819                 Stumblin' In                      CYRIL
# 821     MONTAGEM TOMADA - Slowed                       MXZI
# 822  I Adore You (feat. Daecolm)                      HUGEL
#
#                                                  album release_date  \
# 0    Black Panther The Album Music From And Inspire...   2018-02-09
# 1                                              Starboy   2016-11-25
# ...

# %%
#selecionando colunas específicas, onde os dados sejam maior que 80
file.loc[file["popularity"]>80,["track_name", "popularity"]]
# Out:
#                       track_name  popularity
# 0       All The Stars (with SZA)          95
# 1                        Starboy          90
# 3                     Heat Waves          87
# 4                Let Me Love You          87
# 8                           Baby          84
# ..                           ...         ...
# 813       Thank You (Not So Bad)          85
# 815           I Don't Wanna Wait          85
# 819                 Stumblin' In          86
# 821     MONTAGEM TOMADA - Slowed          81
# 822  I Adore You (feat. Daecolm)          87
#
# [201 rows x 2 columns]

# %% [markdown]
# Indexação  - prátca

# %%
#Acessando múltiplas colunas
file[["popularity","track_name","artist"]]
# Out:
#      popularity                track_name          artist
# 0            95  All The Stars (with SZA)  Kendrick Lamar
# 1            90                   Starboy      The Weeknd
# 2            80                  Señorita    Shawn Mendes
# 3            87                Heat Waves   Glass Animals
# 4            87           Let Me Love You        DJ Snake
# ..          ...                       ...             ...
# 995           0                      Lily           ISAEV
# 996           5                 Apologize       Besomorph
# 997           0                  I’m Good    Yohan Gerber
# 998           1                      Down       Arc North
# 999           0                Chandelier        Besomage
#
# [1000 rows x 3 columns]

# %%
#df.iloc
#Seleção por índice

# %%
help(file.iloc)
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  .. deprecated:: 2.2.0
#  |
#  |     Returning a tuple from a callable is deprecated.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on
#  |    some value.
# ...

# %% [markdown]
# **Ordenação**

# %%
#Ordena de forma decrescente
file.sort_values(by=['release_date','popularity'], ascending = False)
# Out:
#                                  track_name          artist  \
# 826                         Meet Me Halfway         Sandëro
# 828                       Where Are You Now   Nick Giardino
# 845                                   ALONE           NEWER
# 829                             The Monster         Gaullin
# 841                     Boots On The Ground     Dillin Hoox
# ..                                      ...             ...
# 512                        Cheri Cheri Lady  Modern Talking
# 431  Running Up That Hill (A Deal With God)       Kate Bush
# 694                           Smalltown Boy    Bronski Beat
# 602                            Goo Goo Muck      The Cramps
# 517                     Money, Money, Money            ABBA
#
#                      album release_date  popularity  \
# 826        Meet Me Halfway   2025-04-11           4
# 828      Where Are You Now   2025-04-04          37
# 845                  ALONE   2025-04-04          32
# ...

# %%
file.sort_index()
# Out:
#                    track_name          artist  \
# 0    All The Stars (with SZA)  Kendrick Lamar
# 1                     Starboy      The Weeknd
# 2                    Señorita    Shawn Mendes
# 3                  Heat Waves   Glass Animals
# 4             Let Me Love You        DJ Snake
# ..                        ...             ...
# 995                      Lily           ISAEV
# 996                 Apologize       Besomorph
# 997                  I’m Good    Yohan Gerber
# 998                      Down       Arc North
# 999                Chandelier        Besomage
#
#                                                  album release_date  \
# 0    Black Panther The Album Music From And Inspire...   2018-02-09
# 1                                              Starboy   2016-11-25
# 2                                             Señorita   2019-06-21
# 3                                            Dreamland   2020-08-07
# ...
